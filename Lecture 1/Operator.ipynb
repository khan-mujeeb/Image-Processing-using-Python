# %%
num1=int(input("Enter number one "))
num2=int(input("Enter number two "))
print(num1+num2)
print(num1-num2)
print(num1*num2)
print(num1**num2)
print(num1/num2)
print(num1//num2)
print(num1%num2)
# Out:
# Enter number one 6
# Enter number two 2
# 8
# 4
# 12
# 36
# 3.0
# 3
# 0
