# %%
arr = [1, 5, 3, 2, 4]
min = arr[0]
max = arr[0]

for i in range(5):
  if arr[i] < min:
    min = arr[i]
  if arr[i] > max:
    max=arr[i]

print( str(min) +  " is  minimum and " + str(max) + " is maximum")
# Out:
# 1 is  minimum and 5 is maximum
