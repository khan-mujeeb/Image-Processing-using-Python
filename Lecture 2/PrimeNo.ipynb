# %%
num = int(input("Enter a number "))
i=2
count=0
while i< num/2:
  if num%i==0:
    count=1
  i=i+1
if count==0:
  print( str(num) + " is prime")
else:
  print( str(num) + " is not prime")
# Out:
# Enter a number 5
# 5 is prime
